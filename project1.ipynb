# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#import data as i uploaded in the folder it self
file1='./data/data-text.csv'
df1=pd.read_csv(file1)
df1.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# imoport second data set

file2='./data/berlin_weather_oldest.csv'
df2=pd.read_csv(file2)
df2.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df1.describe()
# Out:
#               Year  Display Value      Numeric  Low  High  Comments
# count  4656.000000    4656.000000  4656.000000  0.0   0.0       0.0
# mean   2002.000000      47.194588    47.194588  NaN   NaN       NaN
# std       8.661184      23.843194    23.843194  NaN   NaN       NaN
# min    1990.000000      11.000000    11.000000  NaN   NaN       NaN
# 25%    1997.500000      20.000000    20.000000  NaN   NaN       NaN
# 50%    2000.000000      55.000000    55.000000  NaN   NaN       NaN
# 75%    2012.000000      68.000000    68.000000  NaN   NaN       NaN
# max    2012.000000      87.000000    87.000000  NaN   NaN       NaN

# %%
df2.describe()
# Out:
#                DATE           PRCP           SNWD           SNOW  \
# count  1.172080e+05  117208.000000  117208.000000  117208.000000
# mean   1.956978e+07    -489.543785   -4610.883327   -9781.858363
# std    2.723273e+05    2194.002669    4988.596484    1457.514451
# min    1.900010e+07   -9999.000000   -9999.000000   -9999.000000
# 25%    1.937012e+07       0.000000   -9999.000000   -9999.000000
# 50%    1.960040e+07       0.000000       0.000000   -9999.000000
# 75%    1.980032e+07      14.000000       0.000000   -9999.000000
# max    2.000010e+07    1247.000000    2700.000000     140.000000
#
#                 TMAX           TMIN           WDFG           PGTM  \
# count  117208.000000  117208.000000  117208.000000  117208.000000
# mean        3.150766     -68.517789   -9998.301387   -9998.228602
# std      1135.851895    1096.463087      84.559398      93.482800
# min     -9999.000000   -9999.000000   -9999.000000   -9999.000000
# ...

# %% [markdown]
# #### 1. Get the Metadata from the above files.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df1.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %% [markdown]
# #### 2. Get the row names from the above files.

# %%
df1.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df2.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df1.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %% [markdown]
# #### 3. Change the column name from any of the above file.

# %%
df1.rename(columns={'Indicator':'Indicator_id'}, inplace=True) # single column rename

# %%
df1.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# #### 4. Change the column name from any of the above file and store the changes made permanently.

# %%
#df1.rename(columns=lambda name: (str.title(name)).replace(' ','_'), inplace=True) # using lambda function
df1.rename(columns=lambda name: (str.title(name)), inplace=True) # using lambda function

# %%
df1.head(1)
# Out:
#                        Indicator_Id Publish States  Year Who Region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
#
#   World Bank Income Group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
#
#    High  Comments
# 0   NaN       NaN

# %%
# #removing the '_' using regular expression to '@'
# import re
# df1.rename(columns=lambda name: re.sub(r"\_",'',name), inplace=True) # using lambda function and regular expression

# %%
new_frame = df1.loc[:, ['Indicator_Id','Country','Year', 'Who Region', 'Publish States']]
new_frame.head(5)
# Out:
#                         Indicator_Id               Country  Year  \
# 0   Life expectancy at birth (years)               Andorra  1990
# 1   Life expectancy at birth (years)               Andorra  2000
# 2  Life expectancy at age 60 (years)               Andorra  2012
# 3  Life expectancy at age 60 (years)               Andorra  2000
# 4   Life expectancy at birth (years)  United Arab Emirates  2012
#
#               Who Region Publish States
# 0                 Europe      Published
# 1                 Europe      Published
# 2                 Europe      Published
# 3                 Europe      Published
# 4  Eastern Mediterranean      Published

# %%
df4=new_frame.sort_values(by=['Indicator_Id','Country','Year', 'Who Region', 'Publish States'], ascending=True)
df5=df4.reset_index(drop=True).head(2)
df5.head(2)
# Out:
#                                       Indicator_Id      Country  Year  \
# 0  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 1  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
#
#               Who Region Publish States
# 0  Eastern Mediterranean      Published
# 1  Eastern Mediterranean      Published

# %%
cols=df4.columns.tolist()
print(cols)
df4=df5[['Country', 'Indicator_Id',  'Year', 'Who Region', 'Publish States']]    # making country first column
df4.head(2)
# Out:
# ['Indicator_Id', 'Country', 'Year', 'Who Region', 'Publish States']
#        Country                                     Indicator_Id  Year  \
# 0  Afghanistan  Healthy life expectancy (HALE) at birth (years)  2000
# 1  Afghanistan  Healthy life expectancy (HALE) at birth (years)  2000
#
#               Who Region Publish States
# 0  Eastern Mediterranean      Published
# 1  Eastern Mediterranean      Published

# %%
column1=np.array(df1['Country'])
column1
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
df1.iloc[[11,24, 37],:]
# Out:
#                          Indicator_Id Publish States  Year       Who Region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank Income Group            Country     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %%
#first extract index in np array
n=np.array(df1.index.values)
#df1.sample()
n= np.delete(n, [5,12,23,56], 0)   # delete desired rows
df1.iloc[n].head(10)  # df with all row except 5,12,23,56
# Out:
#                          Indicator_Id Publish States  Year  \
# 0    Life expectancy at birth (years)      Published  1990
# 1    Life expectancy at birth (years)      Published  2000
# 2   Life expectancy at age 60 (years)      Published  2012
# 3   Life expectancy at age 60 (years)      Published  2000
# 4    Life expectancy at birth (years)      Published  2012
# 6   Life expectancy at age 60 (years)      Published  1990
# 7   Life expectancy at age 60 (years)      Published  2012
# 8    Life expectancy at birth (years)      Published  2012
# 9    Life expectancy at birth (years)      Published  2000
# 10   Life expectancy at birth (years)      Published  2012
#
#                Who Region World Bank Income Group               Country  \
# 0                  Europe             High-income               Andorra
# 1                  Europe             High-income               Andorra
# 2                  Europe             High-income               Andorra
# ...

# %% [markdown]
# ### Excercise next

# %%
#first frame user
userDf=pd.read_csv('./data_2/users.csv')
userDf.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessionDf=pd.read_csv('./data_2/sessions.csv')
sessionDf.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
productDf=pd.read_csv('./data_2/products.csv')
productDf.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactionDf=pd.read_csv('./data_2/transactions.csv')
transactionDf.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# #### 12.Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
s1 = pd.merge(transactionDf, userDf, how='left', on=['UserID'])
s1
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# #### 13. Which transactions have a UserID not in users?

# %%
n=set(np.array(transactionDf['UserID']))  # set of user id in transactionDf
n1=set(np.array(userDf['UserID']))        #set of user id in userDf

z=list(n.intersection(n1))        # instersaction

transactionDf.iloc[z]            # selective dataframe
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3

# %% [markdown]
# #### 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
r=pd.merge(transactionDf, userDf, how='inner', on=['UserID'])
r
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# #### 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
r=pd.merge(transactionDf,userDf, how='outer')
r
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# #### 16. Determine which sessions occurred on the same day each user registered

# %%
#solution 1: by pandas sql
import pandasql
from pandasql import sqldf
pysqdf=lambda q: sqldf(q, globals())
# now run query
qry='SELECT u.UserID, u.User, u.Gender, u.Registered, u.Cancelled, s.SessionID,  s.SessionDate from sessionDf s inner join userDf u on s.UserID=u.UserID AND u.Registered=s.SessionDate'
pysqdf(qry)
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17        None          9  2013-07-17

# %%
# # by pandas join
# r=pd.merge(userDf, sessionDf, how='inner', left_on='Registered', right_on='SessionDate')
# r.dropna()

# %% [markdown]
# #### 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
#mannual way
l1=list(userDf['UserID'])
l2=list(productDf['ProductID'])

res = [[i, j] for i in l1 for j in l2]
o1=[]
o2=[]
for item in res:
    o1.append(item[0])
    o2.append(item[1])
dict1={'UserID':o1, 'ProductID':o2}
new_df=pd.DataFrame(data=dict1)
new_df
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
# using pandas multi index

l1=list(userDf['UserID'])
l2=list(productDf['ProductID'])
data = pd.MultiIndex.from_product([l1,l2], names = ["UserID", "ProductID"])

pd.DataFrame(index = data).reset_index()
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
#another way using full ourt join
userDf['key'] = 0
productDf['key'] = 0

df_cartesian = userDf.merge(productDf, how='outer')
print(df_cartesian.columns)
df_cartesian[['UserID','ProductID']]     # dispaly only required columns
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'key',
#        'ProductID', 'Product', 'Price'],
#       dtype='object')
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# #### 18. Determine how much quantity of each product was purchased by each user

# %%
#another way using full ourt join
userDf['key'] = 'same'
productDf['key'] = 'same'
transactionDf['key']='same'

df_cartesian = userDf.merge(productDf, how='outer')
print(df_cartesian.columns)
df1_cartesian=df_cartesian.merge(transactionDf, how='outer')
new_res=df1_cartesian[['UserID','ProductID','Quantity']]     # dispaly only required columns
new_res.fillna(0)
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'key',
#        'ProductID', 'Product', 'Price'],
#       dtype='object')
#     UserID  ProductID  Quantity
# 0      1.0          1       0.0
# 1      1.0          2       3.0
# 2      1.0          3       0.0
# 3      1.0          4       0.0
# 4      1.0          5       0.0
# 5      2.0          1       0.0
# 6      2.0          2       0.0
# 7      2.0          3       0.0
# 8      2.0          4       1.0
# 9      2.0          5       6.0
# 10     3.0          1       0.0
# 11     3.0          2       0.0
# 12     3.0          3       1.0
# 13     3.0          4       1.0
# 14     3.0          4       1.0
# 15     3.0          4       4.0
# 16     3.0          5       0.0
# 17     4.0          1       0.0
# 18     4.0          2       0.0
# 19     4.0          3       0.0
# 20     4.0          4       0.0
# 21     4.0          5       0.0
# 22     5.0          1       0.0
# 23     5.0          2       0.0
# ...

# %% [markdown]
# #### 19. For each user, get each possible pair of pair transactions (TransactionID1,TransacationID2)

# %%
#another way using full ourt join
userDf['key'] = 'same'
productDf['key'] = 'same'
transactionDf['key']='same'

df1=transactionDf.merge(userDf, how='outer')
df1
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity   key  \
# 0             1.0      2010-08-21     7.0        2.0       1.0  same
# 1             9.0      2015-04-24     7.0        4.0       3.0  same
# 2             2.0      2011-05-26     3.0        4.0       1.0  same
# 3             3.0      2011-06-16     3.0        3.0       1.0  same
# 4             7.0      2013-12-30     3.0        4.0       1.0  same
# 5            10.0      2016-05-08     3.0        4.0       4.0  same
# 6             4.0      2012-08-26     1.0        2.0       3.0  same
# 7             5.0      2013-06-06     2.0        4.0       1.0  same
# 8             6.0      2013-12-23     2.0        5.0       6.0  same
# 9             8.0      2014-04-24     NaN        2.0       3.0  same
# 10            NaN             NaN     4.0        NaN       NaN  same
# 11            NaN             NaN     5.0        NaN       NaN  same
#
#         User  Gender  Registered   Cancelled
# ...

# %%
df2=transactionDf.merge(productDf, how='outer')
df2
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity   key Product  \
# 0             1.0      2010-08-21     7.0          2       1.0  same       B
# 1             4.0      2012-08-26     1.0          2       3.0  same       B
# 2             8.0      2014-04-24     NaN          2       3.0  same       B
# 3             2.0      2011-05-26     3.0          4       1.0  same       D
# 4             5.0      2013-06-06     2.0          4       1.0  same       D
# 5             7.0      2013-12-30     3.0          4       1.0  same       D
# 6             9.0      2015-04-24     7.0          4       3.0  same       D
# 7            10.0      2016-05-08     3.0          4       4.0  same       D
# 8             3.0      2011-06-16     3.0          3       1.0  same       C
# 9             6.0      2013-12-23     2.0          5       6.0  same       E
# 10            NaN             NaN     NaN          1       NaN  same       A
#
#     Price
# 0   33.04
# 1   33.04
# ...

# %%
df3=df1.merge(df2, how='outer')
df3
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity   key  \
# 0             1.0      2010-08-21     7.0        2.0       1.0  same
# 1             9.0      2015-04-24     7.0        4.0       3.0  same
# 2             2.0      2011-05-26     3.0        4.0       1.0  same
# 3             3.0      2011-06-16     3.0        3.0       1.0  same
# 4             7.0      2013-12-30     3.0        4.0       1.0  same
# 5            10.0      2016-05-08     3.0        4.0       4.0  same
# 6             4.0      2012-08-26     1.0        2.0       3.0  same
# 7             5.0      2013-06-06     2.0        4.0       1.0  same
# 8             6.0      2013-12-23     2.0        5.0       6.0  same
# 9             8.0      2014-04-24     NaN        2.0       3.0  same
# 10            NaN             NaN     4.0        NaN       NaN  same
# 11            NaN             NaN     5.0        NaN       NaN  same
# 12            NaN             NaN     NaN        1.0       NaN  same
#
# ...

# %% [markdown]
# #### 20. Join each user to his/her first occuring transaction in the transactions table

# %%
df23=userDf.merge(transactionDf, how='left', on='UserID')
df23.drop_duplicates(subset ="UserID", keep='first', inplace=True)
df23
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 3       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 7       4   Brielle  female  2013-07-17         NaN            NaN
# 8       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 3      2011-05-26        4.0       1.0
# 7             NaN        NaN       NaN
# 8             NaN        NaN       NaN

# %% [markdown]
# #### 21. Test to see if we can drop columns

# %%
df23.drop(columns=['Cancelled'])
# Out:
#    UserID      User  Gender  Registered  TransactionID TransactionDate  \
# 0       1   Charles    male  2012-12-21            4.0      2012-08-26
# 1       2     Pedro    male  2010-08-01            5.0      2013-06-06
# 3       3  Caroline  female  2012-10-23            2.0      2011-05-26
# 7       4   Brielle  female  2013-07-17            NaN             NaN
# 8       5  Benjamin    male  2010-11-25            NaN             NaN
#
#    ProductID  Quantity
# 0        2.0       3.0
# 1        4.0       1.0
# 3        4.0       1.0
# 7        NaN       NaN
# 8        NaN       NaN

# %%
#list of frame cols
my_columns = list(df23.columns)
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
#list of frame clos with 90% NA thresh---refined on columns basis
list(df23.dropna(thresh=int(df23.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
list(df23.dropna(thresh=int(df23.shape[0] * .9), axis=0).columns)   #rowwise thresh hold
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
# cols list if contains atleast one null value
missing_info= list(df23.columns[df23.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
#printing number of total missing values in a particular column
for col in missing_info:
    num_missing = df23[df23[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
 # print(df23.shape[0]) number of rows
#finding percentage of missing values column-wise
for col in missing_info:
    percent_missing = df23[df23[col].isnull() == True].shape[0]/df23.shape[0] 
    print('percent missing for column {}: {}'.format( col, percent_missing))
# Out:
# 5
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4

# %%
Help References:
    
    Various internet sources:
        
        1. https://github.com
        2. google
